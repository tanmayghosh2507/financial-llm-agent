# %%
pip install phidata
# Out:
# Requirement already satisfied: phidata in /Users/tanmayghosh/venv/lib/python3.12/site-packages (2.7.10)
# Requirement already satisfied: docstring-parser in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from phidata) (0.17.0)
# Requirement already satisfied: gitpython in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from phidata) (3.1.45)
# Requirement already satisfied: httpx in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from phidata) (0.28.1)
# Requirement already satisfied: pydantic in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from phidata) (2.12.4)
# Requirement already satisfied: pydantic-settings in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from phidata) (2.12.0)
# Requirement already satisfied: python-dotenv in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from phidata) (1.2.1)
# Requirement already satisfied: pyyaml in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from phidata) (6.0.3)
# Requirement already satisfied: rich in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from phidata) (14.2.0)
# Requirement already satisfied: tomli in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from phidata) (2.3.0)
# Requirement already satisfied: typer in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from phidata) (0.20.0)
# Requirement already satisfied: typing-extensions in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from phidata) (4.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from gitpython->phidata) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython->phidata) (5.0.2)
# Requirement already satisfied: anyio in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from httpx->phidata) (4.11.0)
# Requirement already satisfied: certifi in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from httpx->phidata) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from httpx->phidata) (1.0.9)
# Requirement already satisfied: idna in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from httpx->phidata) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->phidata) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from anyio->httpx->phidata) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from pydantic->phidata) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from pydantic->phidata) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from pydantic->phidata) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from rich->phidata) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from rich->phidata) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->phidata) (0.1.2)
# Requirement already satisfied: click>=8.0.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from typer->phidata) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from typer->phidata) (1.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastapi
# Out:
# Collecting fastapi
#   Downloading fastapi-0.121.2-py3-none-any.whl.metadata (28 kB)
# Collecting starlette<0.50.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.49.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from fastapi) (2.12.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from fastapi) (4.15.0)
# Collecting annotated-doc>=0.0.2 (from fastapi)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from starlette<0.50.0,>=0.40.0->fastapi) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (1.3.1)
# Downloading fastapi-0.121.2-py3-none-any.whl (109 kB)
# Downloading starlette-0.49.3-py3-none-any.whl (74 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Installing collected packages: annotated-doc, starlette, fastapi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [fastapi]
# Successfully installed annotated-doc-0.0.4 fastapi-0.121.2 starlette-0.49.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.66-py2.py3-none-any.whl.metadata (6.0 kB)
# Collecting pandas>=1.3.0 (from yfinance)
#   Downloading pandas-2.3.3-cp312-cp312-macosx_10_13_x86_64.whl.metadata (91 kB)
# Collecting numpy>=1.16.5 (from yfinance)
#   Downloading numpy-2.3.4-cp312-cp312-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting requests>=2.31 (from yfinance)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from yfinance) (4.5.0)
# Collecting pytz>=2022.5 (from yfinance)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.3.tar.gz (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 11.7 MB/s  0:00:00 eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Downloading beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-macosx_10_9_x86_64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-15.0.1-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.11.1->yfinance)
#   Using cached soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Collecting cffi>=1.12.0 (from curl_cffi>=0.7->yfinance)
#   Downloading cffi-2.0.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: certifi>=2024.2.2 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (2025.11.12)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi>=0.7->yfinance)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Collecting tzdata>=2022.7 (from pandas>=1.3.0->yfinance)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.31->yfinance)
#   Downloading charset_normalizer-3.4.4-cp312-cp312-macosx_10_13_universal2.whl.metadata (37 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.11)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31->yfinance)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Downloading yfinance-0.2.66-py2.py3-none-any.whl (123 kB)
# Downloading beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-macosx_10_9_x86_64.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 7.0 MB/s  0:00:00 eta 0:00:01
# Downloading cffi-2.0.0-cp312-cp312-macosx_10_13_x86_64.whl (185 kB)
# Downloading frozendict-2.4.7-py3-none-any.whl (16 kB)
# Downloading numpy-2.3.4-cp312-cp312-macosx_14_0_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 5.2 MB/s  0:00:01 eta 0:00:01
# Downloading pandas-2.3.3-cp312-cp312-macosx_10_13_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 4.3 MB/s  0:00:02 eta 0:00:01
# Downloading protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp312-cp312-macosx_10_13_universal2.whl (208 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached soupsieve-2.8-py3-none-any.whl (36 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading websockets-15.0.1-cp312-cp312-macosx_10_13_x86_64.whl (173 kB)
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Building wheels for collected packages: multitasking, peewee
#   Building wheel for multitasking (pyproject.toml) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15636 sha256=c4340f3512c25b8cd1ded5b4d67b8d0f3c37a051b616b90ce87c2b5c504d7da9
#   Stored in directory: /Users/tanmayghosh/Library/Caches/pip/wheels/cc/bd/6f/664d62c99327abeef7d86489e6631cbf45b56fbf7ef1d6ef00
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.18.3-cp312-cp312-macosx_10_15_x86_64.whl size=276132 sha256=211cf530891967ddbdec844743522a8ec8d563a9c1ae8d1f42a1793be1dea1a4
#   Stored in directory: /Users/tanmayghosh/Library/Caches/pip/wheels/e2/48/b6/675a31c56e50b8b343e1ffbb1d9209f0d95025e2cfa0bbeeed
# Successfully built multitasking peewee
# Installing collected packages: pytz, peewee, multitasking, websockets, urllib3, tzdata, soupsieve, pycparser, protobuf, numpy, frozendict, charset_normalizer, requests, pandas, cffi, beautifulsoup4, curl_cffi, yfinance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [yfinance]/18 [yfinance]]
# Successfully installed beautifulsoup4-4.14.2 cffi-2.0.0 charset_normalizer-3.4.4 curl_cffi-0.13.0 frozendict-2.4.7 multitasking-0.0.12 numpy-2.3.4 pandas-2.3.3 peewee-3.18.3 protobuf-6.33.1 pycparser-2.23 pytz-2025.2 requests-2.32.5 soupsieve-2.8 tzdata-2025.2 urllib3-2.5.0 websockets-15.0.1 yfinance-0.2.66
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install duckduckgo-search
# Out:
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: click>=8.1.8 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from duckduckgo-search) (8.3.1)
# Collecting primp>=0.15.0 (from duckduckgo-search)
#   Downloading primp-0.15.0-cp38-abi3-macosx_10_12_x86_64.whl.metadata (13 kB)
# Collecting lxml>=5.3.0 (from duckduckgo-search)
#   Downloading lxml-6.0.2-cp312-cp312-macosx_10_13_x86_64.whl.metadata (3.6 kB)
# Downloading duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Downloading lxml-6.0.2-cp312-cp312-macosx_10_13_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 7.5 MB/s  0:00:00 eta 0:00:01
# Downloading primp-0.15.0-cp38-abi3-macosx_10_12_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 8.7 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: primp, lxml, duckduckgo-search
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [duckduckgo-search]duckduckgo-search]
# Successfully installed duckduckgo-search-8.1.1 lxml-6.0.2 primp-0.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /Users/tanmayghosh/venv/lib/python3.12/site-packages (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install uvicorn
# Out:
# Collecting uvicorn
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: click>=7.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from uvicorn) (0.16.0)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Installing collected packages: uvicorn
# Successfully installed uvicorn-0.38.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install packaging
# Out:
# Requirement already satisfied: packaging in /Users/tanmayghosh/venv/lib/python3.12/site-packages (25.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-2.8.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from openai) (4.11.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.12.0-cp312-cp312-macosx_10_12_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from openai) (1.3.1)
# Collecting tqdm>4 (from openai)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Downloading openai-2.8.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 11.4 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.12.0-cp312-cp312-macosx_10_12_x86_64.whl (314 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, jiter, distro, openai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [openai]2m3/4 [openai]
# Successfully installed distro-1.9.0 jiter-0.12.0 openai-2.8.0 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install groq
# Out:
# Collecting groq
#   Downloading groq-0.34.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from groq) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from groq) (2.12.4)
# Requirement already satisfied: sniffio in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/tanmayghosh/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-0.34.1-py3-none-any.whl (136 kB)
# Installing collected packages: groq
# Successfully installed groq-0.34.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from phi.agent import Agent
from phi.model.groq import Groq
from phi.tools.yfinance import YFinanceTools
from phi.tools.duckduckgo import DuckDuckGo
from phi.model.openai import OpenAIChat
import openai
import os
from dotenv import load_dotenv

# %%
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
web_search_agent = Agent(
    name="Financial Web Search Agent",
    role="Search the web for financial information using DuckDuckGo and provide accurate responses.",
    model=OpenAIChat(id="gpt-4o"), #"grok-preview",
    tools=[DuckDuckGo()],
    instructions=["Always include source and use markdown formatting."],
    show_tool_calls=True,
    markdown=True
)

# %%
web_search_agent.print_response("Tell me about OpenAI Sora?", stream=True)
# Out:
# /Users/tanmayghosh/venv/lib/python3.12/site-packages/rich/live.py:256: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 web_search_agent.print_response("Tell me about OpenAI Sora?", stream=True)
#
# File ~/venv/lib/python3.12/site-packages/phi/agent/agent.py:2825, in Agent.print_response(self, message, messages, stream, markdown, show_message, show_reasoning, show_full_reasoning, console, **kwargs)
#    2822 if render:
#    2823     live_log.update(Group(*panels))
# -> 2825 for resp in self.run(message=message, messages=messages, stream=True, **kwargs):
#    2826     if isinstance(resp, RunResponse) and isinstance(resp.content, str):
#    2827         if resp.event == RunEvent.run_response:
#
# File ~/venv/lib/python3.12/site-packages/phi/agent/agent.py:1805, in Agent._run(self, message, stream, audio, images, videos, messages, stream_intermediate_steps, **kwargs)
#    1803 if self.stream:
#    1804     model_response = ModelResponse(content="")
# -> 1805     for model_response_chunk in self.model.response_stream(messages=messages_for_model):
#    1806         if model_response_chunk.event == ModelResponseEvent.assistant_response.value:
#    1807             if model_response_chunk.content is not None and model_response.content is not None:
#
# File ~/venv/lib/python3.12/site-packages/phi/model/openai/chat.py:872, in OpenAIChat.response_stream(self, messages)
#     870 # -*- Generate response
#     871 metrics.response_timer.start()
# --> 872 for response in self.invoke_stream(messages=messages):
#     873     if len(response.choices) > 0:
#     874         metrics.completion_tokens += 1
#
# File ~/venv/lib/python3.12/site-packages/phi/model/openai/chat.py:396, in OpenAIChat.invoke_stream(self, messages)
#     386 def invoke_stream(self, messages: List[Message]) -> Iterator[ChatCompletionChunk]:
#     387     """
#     388     Send a streaming chat completion request to the OpenAI API.
#     389
#    (...)    394         Iterator[ChatCompletionChunk]: An iterator of chat completion chunks.
#     395     """
# --> 396     yield from self.get_client().chat.completions.create(
#     397         model=self.id,
#     398         messages=[self.format_message(m) for m in messages],  # type: ignore
#     399         stream=True,
#     400         stream_options={"include_usage": True},
#     401         **self.request_kwargs,
#     402     )
#
# File ~/venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1189, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1142 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1143 def create(
#    1144     self,
#    (...)   1186     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1187 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1188     validate_response_format(response_format)
# -> 1189     return self._post(
#    1190         "/chat/completions",
#    1191         body=maybe_transform(
#    1192             {
#    1193                 "messages": messages,
#    1194                 "model": model,
#    1195                 "audio": audio,
#    1196                 "frequency_penalty": frequency_penalty,
#    1197                 "function_call": function_call,
#    1198                 "functions": functions,
#    1199                 "logit_bias": logit_bias,
#    1200                 "logprobs": logprobs,
#    1201                 "max_completion_tokens": max_completion_tokens,
#    1202                 "max_tokens": max_tokens,
#    1203                 "metadata": metadata,
#    1204                 "modalities": modalities,
#    1205                 "n": n,
#    1206                 "parallel_tool_calls": parallel_tool_calls,
#    1207                 "prediction": prediction,
#    1208                 "presence_penalty": presence_penalty,
#    1209                 "prompt_cache_key": prompt_cache_key,
#    1210                 "prompt_cache_retention": prompt_cache_retention,
#    1211                 "reasoning_effort": reasoning_effort,
#    1212                 "response_format": response_format,
#    1213                 "safety_identifier": safety_identifier,
#    1214                 "seed": seed,
#    1215                 "service_tier": service_tier,
#    1216                 "stop": stop,
#    1217                 "store": store,
#    1218                 "stream": stream,
#    1219                 "stream_options": stream_options,
#    1220                 "temperature": temperature,
#    1221                 "tool_choice": tool_choice,
#    1222                 "tools": tools,
#    1223                 "top_logprobs": top_logprobs,
#    1224                 "top_p": top_p,
#    1225                 "user": user,
#    1226                 "verbosity": verbosity,
#    1227                 "web_search_options": web_search_options,
#    1228             },
#    1229             completion_create_params.CompletionCreateParamsStreaming
#    1230             if stream
#    1231             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1232         ),
#    1233         options=make_request_options(
#    1234             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1235         ),
#    1236         cast_to=ChatCompletion,
#    1237         stream=stream or False,
#    1238         stream_cls=Stream[ChatCompletionChunk],
#    1239     )
#
# File ~/venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
